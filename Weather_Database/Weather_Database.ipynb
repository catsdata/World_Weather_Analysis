# %%
#Create a new set of 2,000 random latitudes and longitudes.

#Get the nearest city using the citipy module.

#Perform an API call with the OpenWeatherMap.

#Retrieve the following information from the API call:

    #Latitude and longitude
    #Maximum temperature
    #Percent humidity
    #Percent cloudiness
    #Wind speed
    #Weather description (for example, clouds, fog, light rain, clear sky)

#Add the data to a new DataFrame.

#Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

#Be sure to double-check that you have the following in the Weather_Database folder:

    #The Weather_Database.ipynb file
    #The WeatherPy_Database.csv file

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3c95f0d0ef08ff2d83b62b6ee1847479

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(2)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | cidreira
# Processing Record 4 of Set 1 | tungkang
# City not found. Skipping...
# Processing Record 5 of Set 1 | orotukan
# Processing Record 6 of Set 1 | damietta
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | bambous virieux
# Processing Record 9 of Set 1 | dingle
# Processing Record 10 of Set 1 | pietersburg
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | grand gaube
# Processing Record 15 of Set 1 | arraial do cabo
# Processing Record 16 of Set 1 | sola
# Processing Record 17 of Set 1 | luderitz
# Processing Record 18 of Set 1 | provideniya
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | torbay
# Processing Record 21 of Set 1 | sile
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | flinders
# Processing Record 24 of Set 1 | tuatapere
# Processing Record 25 of Set 1 | yeppoon
# Processing Record 26 of Set 1 | batouri
# Processing Record 27 of Set 1 | ullapool
# Processing Record 28 of Set 1 | kaifeng
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | acapulco
# Processing Record 31 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 1 | dickinson
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | seminole
# Processing Record 36 of Set 1 | kavieng
# Processing Record 37 of Set 1 | tuktoyaktuk
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | katsuura
# Processing Record 40 of Set 1 | ucluelet
# Processing Record 41 of Set 1 | saint-philippe
# Processing Record 42 of Set 1 | madera
# Processing Record 43 of Set 1 | goedereede
# Processing Record 44 of Set 1 | albany
# Processing Record 45 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 1 | mnogovershinnyy
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | carnarvon
# Processing Record 49 of Set 1 | sao jose da coroa grande
# Processing Record 50 of Set 1 | tupelo
# Processing Record 1 of Set 2 | magrath
# Processing Record 2 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | buala
# Processing Record 5 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 6 of Set 2 | codrington
# Processing Record 7 of Set 2 | nikolskoye
# Processing Record 8 of Set 2 | saint george
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | mitu
# Processing Record 11 of Set 2 | okandja
# City not found. Skipping...
# Processing Record 12 of Set 2 | bandundu
# Processing Record 13 of Set 2 | platteville
# Processing Record 14 of Set 2 | norman wells
# Processing Record 15 of Set 2 | poronaysk
# Processing Record 16 of Set 2 | houston
# Processing Record 17 of Set 2 | georgetown
# Processing Record 18 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 2 | nhamunda
# Processing Record 20 of Set 2 | vaini
# Processing Record 21 of Set 2 | grand-santi
# Processing Record 22 of Set 2 | tiksi
# Processing Record 23 of Set 2 | ongandjera
# Processing Record 24 of Set 2 | quelimane
# Processing Record 25 of Set 2 | port alfred
# Processing Record 26 of Set 2 | ambatolampy
# Processing Record 27 of Set 2 | manaure
# Processing Record 28 of Set 2 | yukhnov
# Processing Record 29 of Set 2 | koumac
# Processing Record 30 of Set 2 | port blair
# Processing Record 31 of Set 2 | debre tabor
# Processing Record 32 of Set 2 | maniwaki
# Processing Record 33 of Set 2 | cabra
# Processing Record 34 of Set 2 | gurupi
# Processing Record 35 of Set 2 | sondrio
# Processing Record 36 of Set 2 | tasiilaq
# Processing Record 37 of Set 2 | butaritari
# Processing Record 38 of Set 2 | okha
# Processing Record 39 of Set 2 | te anau
# Processing Record 40 of Set 2 | healdsburg
# Processing Record 41 of Set 2 | thompson
# Processing Record 42 of Set 2 | gbadolite
# Processing Record 43 of Set 2 | nome
# Processing Record 44 of Set 2 | binika
# Processing Record 45 of Set 2 | marienburg
# Processing Record 46 of Set 2 | nizhnyaya tavda
# Processing Record 47 of Set 2 | maceio
# Processing Record 48 of Set 2 | gazojak
# Processing Record 49 of Set 2 | sitka
# Processing Record 50 of Set 2 | qaanaaq
# Processing Record 1 of Set 3 | cabo san lucas
# Processing Record 2 of Set 3 | cape town
# Processing Record 3 of Set 3 | mopipi
# Processing Record 4 of Set 3 | kavaratti
# Processing Record 5 of Set 3 | yoichi
# Processing Record 6 of Set 3 | pangnirtung
# Processing Record 7 of Set 3 | moerai
# Processing Record 8 of Set 3 | yurty
# Processing Record 9 of Set 3 | namibe
# Processing Record 10 of Set 3 | biak
# Processing Record 11 of Set 3 | salalah
# Processing Record 12 of Set 3 | balsas
# Processing Record 13 of Set 3 | hermanus
# Processing Record 14 of Set 3 | beira
# Processing Record 15 of Set 3 | chuy
# Processing Record 16 of Set 3 | prince rupert
# Processing Record 17 of Set 3 | yulara
# Processing Record 18 of Set 3 | jahrom
# City not found. Skipping...
# Processing Record 19 of Set 3 | rocha
# Processing Record 20 of Set 3 | new norfolk
# Processing Record 21 of Set 3 | jeremie
# Processing Record 22 of Set 3 | crestview
# Processing Record 23 of Set 3 | lebu
# Processing Record 24 of Set 3 | ambodifototra
# City not found. Skipping...
# Processing Record 25 of Set 3 | ancud
# Processing Record 26 of Set 3 | kaitangata
# Processing Record 27 of Set 3 | akom
# Processing Record 28 of Set 3 | taitung
# Processing Record 29 of Set 3 | natal
# Processing Record 30 of Set 3 | pisco
# Processing Record 31 of Set 3 | padang
# Processing Record 32 of Set 3 | kodiak
# Processing Record 33 of Set 3 | dalby
# Processing Record 34 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 3 | hohhot
# Processing Record 36 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 3 | namatanai
# Processing Record 38 of Set 3 | templin
# Processing Record 39 of Set 3 | nago
# Processing Record 40 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 3 | hithadhoo
# Processing Record 42 of Set 3 | avarua
# Processing Record 43 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 3 | san angelo
# Processing Record 45 of Set 3 | airai
# Processing Record 46 of Set 3 | mezen
# Processing Record 47 of Set 3 | bathsheba
# Processing Record 48 of Set 3 | vila franca do campo
# Processing Record 49 of Set 3 | tiarei
# Processing Record 50 of Set 3 | yangambi
# Processing Record 1 of Set 4 | east london
# Processing Record 2 of Set 4 | yuncheng
# Processing Record 3 of Set 4 | ostrovnoy
# Processing Record 4 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 4 | nemuro
# Processing Record 6 of Set 4 | crab hill
# City not found. Skipping...
# Processing Record 7 of Set 4 | mount pleasant
# Processing Record 8 of Set 4 | luoyang
# Processing Record 9 of Set 4 | virginia beach
# Processing Record 10 of Set 4 | bubaque
# Processing Record 11 of Set 4 | belmonte
# Processing Record 12 of Set 4 | ilulissat
# Processing Record 13 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 4 | aasiaat
# Processing Record 15 of Set 4 | portland
# Processing Record 16 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 4 | taltal
# Processing Record 19 of Set 4 | ponta do sol
# Processing Record 20 of Set 4 | mount gambier
# Processing Record 21 of Set 4 | morondava
# Processing Record 22 of Set 4 | kaputa
# Processing Record 23 of Set 4 | husavik
# Processing Record 24 of Set 4 | lavrentiya
# Processing Record 25 of Set 4 | aktash
# Processing Record 26 of Set 4 | ahipara
# Processing Record 27 of Set 4 | kisangani
# Processing Record 28 of Set 4 | bertoua
# Processing Record 29 of Set 4 | saskylakh
# Processing Record 30 of Set 4 | umm lajj
# Processing Record 31 of Set 4 | ketchikan
# Processing Record 32 of Set 4 | shuiji
# Processing Record 33 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 4 | broome
# Processing Record 35 of Set 4 | saint-augustin
# Processing Record 36 of Set 4 | castro
# Processing Record 37 of Set 4 | raudeberg
# Processing Record 38 of Set 4 | bulanash
# Processing Record 39 of Set 4 | esperance
# Processing Record 40 of Set 4 | sirjan
# Processing Record 41 of Set 4 | svecha
# Processing Record 42 of Set 4 | cherskiy
# Processing Record 43 of Set 4 | kailua
# Processing Record 44 of Set 4 | teguise
# Processing Record 45 of Set 4 | xichang
# Processing Record 46 of Set 4 | hasaki
# Processing Record 47 of Set 4 | solwezi
# Processing Record 48 of Set 4 | akyab
# Processing Record 49 of Set 4 | plouzane
# Processing Record 50 of Set 4 | laguna
# Processing Record 1 of Set 5 | meulaboh
# Processing Record 2 of Set 5 | arrifes
# Processing Record 3 of Set 5 | poopo
# Processing Record 4 of Set 5 | mareeba
# Processing Record 5 of Set 5 | pevek
# Processing Record 6 of Set 5 | buta
# Processing Record 7 of Set 5 | qasigiannguit
# Processing Record 8 of Set 5 | deputatskiy
# Processing Record 9 of Set 5 | puerto ayora
# Processing Record 10 of Set 5 | seymchan
# Processing Record 11 of Set 5 | nam tha
# City not found. Skipping...
# Processing Record 12 of Set 5 | brejo
# Processing Record 13 of Set 5 | souillac
# Processing Record 14 of Set 5 | talnakh
# Processing Record 15 of Set 5 | puerto baquerizo moreno
# Processing Record 16 of Set 5 | lewisporte
# Processing Record 17 of Set 5 | severo-kurilsk
# Processing Record 18 of Set 5 | ust-tsilma
# Processing Record 19 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 5 | batsfjord
# Processing Record 21 of Set 5 | cozumel
# Processing Record 22 of Set 5 | gornopravdinsk
# Processing Record 23 of Set 5 | aleksandrov gay
# Processing Record 24 of Set 5 | gillette
# Processing Record 25 of Set 5 | khanpur
# Processing Record 26 of Set 5 | saldanha
# Processing Record 27 of Set 5 | teguldet
# Processing Record 28 of Set 5 | mar del plata
# Processing Record 29 of Set 5 | dikson
# Processing Record 30 of Set 5 | kieta
# Processing Record 31 of Set 5 | horki
# Processing Record 32 of Set 5 | aklavik
# Processing Record 33 of Set 5 | bangad
# Processing Record 34 of Set 5 | tacuati
# Processing Record 35 of Set 5 | bida
# Processing Record 36 of Set 5 | chernyshevskiy
# Processing Record 37 of Set 5 | rafraf
# Processing Record 38 of Set 5 | pajapan
# Processing Record 39 of Set 5 | sangar
# Processing Record 40 of Set 5 | wexford
# Processing Record 41 of Set 5 | west odessa
# Processing Record 42 of Set 5 | suntar
# Processing Record 43 of Set 5 | tandil
# Processing Record 44 of Set 5 | rio grande
# Processing Record 45 of Set 5 | nhulunbuy
# Processing Record 46 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 47 of Set 5 | dudinka
# Processing Record 48 of Set 5 | los llanos de aridane
# Processing Record 49 of Set 5 | ribeira grande
# Processing Record 50 of Set 5 | buchanan
# Processing Record 1 of Set 6 | klaksvik
# Processing Record 2 of Set 6 | petropavl
# Processing Record 3 of Set 6 | khatanga
# Processing Record 4 of Set 6 | tromso
# Processing Record 5 of Set 6 | peace river
# Processing Record 6 of Set 6 | sorland
# Processing Record 7 of Set 6 | yanji
# Processing Record 8 of Set 6 | kawasaki
# Processing Record 9 of Set 6 | bethel
# Processing Record 10 of Set 6 | kilcormac
# Processing Record 11 of Set 6 | candelaria
# Processing Record 12 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 6 | chicama
# Processing Record 14 of Set 6 | bershet
# Processing Record 15 of Set 6 | agadir
# Processing Record 16 of Set 6 | matara
# Processing Record 17 of Set 6 | tillabery
# City not found. Skipping...
# Processing Record 18 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 19 of Set 6 | luanda
# Processing Record 20 of Set 6 | mosquera
# Processing Record 21 of Set 6 | saint-georges
# Processing Record 22 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 23 of Set 6 | taoudenni
# Processing Record 24 of Set 6 | harper
# Processing Record 25 of Set 6 | port-gentil
# Processing Record 26 of Set 6 | mahebourg
# Processing Record 27 of Set 6 | shush
# Processing Record 28 of Set 6 | port lincoln
# Processing Record 29 of Set 6 | muros
# Processing Record 30 of Set 6 | lewistown
# Processing Record 31 of Set 6 | geraldton
# Processing Record 32 of Set 6 | whitehorse
# Processing Record 33 of Set 6 | safonovo
# Processing Record 34 of Set 6 | qurayyat
# Processing Record 35 of Set 6 | bengkulu
# Processing Record 36 of Set 6 | san policarpo
# Processing Record 37 of Set 6 | marsa matruh
# Processing Record 38 of Set 6 | songkhla
# Processing Record 39 of Set 6 | upernavik
# Processing Record 40 of Set 6 | maldonado
# Processing Record 41 of Set 6 | havre-saint-pierre
# Processing Record 42 of Set 6 | sao filipe
# Processing Record 43 of Set 6 | langenburg
# Processing Record 44 of Set 6 | yerbogachen
# Processing Record 45 of Set 6 | fez
# Processing Record 46 of Set 6 | manoel urbano
# Processing Record 47 of Set 6 | lagoa
# Processing Record 48 of Set 6 | wenling
# Processing Record 49 of Set 6 | beloha
# Processing Record 50 of Set 6 | dali
# Processing Record 1 of Set 7 | balykshi
# Processing Record 2 of Set 7 | okhotsk
# Processing Record 3 of Set 7 | worland
# Processing Record 4 of Set 7 | dongying
# Processing Record 5 of Set 7 | okhtyrka
# Processing Record 6 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 7 | kruisfontein
# Processing Record 8 of Set 7 | dunedin
# Processing Record 9 of Set 7 | chenzhou
# Processing Record 10 of Set 7 | derzhavinsk
# Processing Record 11 of Set 7 | mogadishu
# Processing Record 12 of Set 7 | santo domingo
# Processing Record 13 of Set 7 | balkanabat
# Processing Record 14 of Set 7 | eidfjord
# Processing Record 15 of Set 7 | korla
# Processing Record 16 of Set 7 | eskil
# Processing Record 17 of Set 7 | traverse city
# Processing Record 18 of Set 7 | caravelas
# Processing Record 19 of Set 7 | iqaluit
# Processing Record 20 of Set 7 | rokytne
# Processing Record 21 of Set 7 | lubao
# Processing Record 22 of Set 7 | vsevolodo-vilva
# City not found. Skipping...
# Processing Record 23 of Set 7 | shimoda
# Processing Record 24 of Set 7 | urumqi
# Processing Record 25 of Set 7 | hilo
# Processing Record 26 of Set 7 | murdochville
# Processing Record 27 of Set 7 | isangel
# Processing Record 28 of Set 7 | adiake
# Processing Record 29 of Set 7 | port macquarie
# Processing Record 30 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 31 of Set 7 | muzhi
# Processing Record 32 of Set 7 | jumla
# Processing Record 33 of Set 7 | ahuimanu
# Processing Record 34 of Set 7 | oranjestad
# Processing Record 35 of Set 7 | jacareacanga
# Processing Record 36 of Set 7 | karoi
# Processing Record 37 of Set 7 | kimi
# City not found. Skipping...
# Processing Record 38 of Set 7 | sao felix do xingu
# Processing Record 39 of Set 7 | alofi
# Processing Record 40 of Set 7 | bay city
# Processing Record 41 of Set 7 | poum
# Processing Record 42 of Set 7 | kaeo
# Processing Record 43 of Set 7 | beaverlodge
# Processing Record 44 of Set 7 | carauari
# Processing Record 45 of Set 7 | hualmay
# Processing Record 46 of Set 7 | mandurah
# Processing Record 47 of Set 7 | marystown
# Processing Record 48 of Set 7 | brindisi
# Processing Record 49 of Set 7 | kajaani
# Processing Record 50 of Set 7 | lixourion
# Processing Record 1 of Set 8 | lompoc
# Processing Record 2 of Set 8 | wajir
# Processing Record 3 of Set 8 | tororo
# Processing Record 4 of Set 8 | mantua
# Processing Record 5 of Set 8 | coquimbo
# Processing Record 6 of Set 8 | general zuazua
# Processing Record 7 of Set 8 | banda aceh
# Processing Record 8 of Set 8 | camacha
# Processing Record 9 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 10 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 8 | grindavik
# Processing Record 12 of Set 8 | sisimiut
# Processing Record 13 of Set 8 | pacific grove
# Processing Record 14 of Set 8 | regeneracao
# Processing Record 15 of Set 8 | sao joao da barra
# Processing Record 16 of Set 8 | sergeyevka
# Processing Record 17 of Set 8 | hofn
# Processing Record 18 of Set 8 | lar gerd
# City not found. Skipping...
# Processing Record 19 of Set 8 | pokhara
# Processing Record 20 of Set 8 | malanje
# Processing Record 21 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 8 | ixtapa
# Processing Record 23 of Set 8 | vaitape
# Processing Record 24 of Set 8 | minab
# Processing Record 25 of Set 8 | rio verde de mato grosso
# Processing Record 26 of Set 8 | khasan
# Processing Record 27 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 8 | yinchuan
# Processing Record 29 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 8 | srednekolymsk
# Processing Record 31 of Set 8 | talara
# Processing Record 32 of Set 8 | ann arbor
# Processing Record 33 of Set 8 | howard springs
# Processing Record 34 of Set 8 | high level
# Processing Record 35 of Set 8 | san lawrenz
# Processing Record 36 of Set 8 | longyearbyen
# Processing Record 37 of Set 8 | cayenne
# Processing Record 38 of Set 8 | kurumkan
# Processing Record 39 of Set 8 | faanui
# Processing Record 40 of Set 8 | santa cruz de tenerife
# Processing Record 41 of Set 8 | paide
# Processing Record 42 of Set 8 | vao
# Processing Record 43 of Set 8 | hambantota
# Processing Record 44 of Set 8 | tsiroanomandidy
# Processing Record 45 of Set 8 | japura
# Processing Record 46 of Set 8 | ikwiriri
# Processing Record 47 of Set 8 | inhambane
# Processing Record 48 of Set 8 | victor harbor
# Processing Record 49 of Set 8 | san patricio
# Processing Record 50 of Set 8 | noumea
# Processing Record 1 of Set 9 | byron bay
# Processing Record 2 of Set 9 | aykhal
# Processing Record 3 of Set 9 | purranque
# Processing Record 4 of Set 9 | inirida
# Processing Record 5 of Set 9 | tilichiki
# Processing Record 6 of Set 9 | xapuri
# Processing Record 7 of Set 9 | chernoyerkovskaya
# Processing Record 8 of Set 9 | skegness
# Processing Record 9 of Set 9 | haapu
# City not found. Skipping...
# Processing Record 10 of Set 9 | pishin
# Processing Record 11 of Set 9 | prince albert
# Processing Record 12 of Set 9 | beder
# Processing Record 13 of Set 9 | caucaia
# Processing Record 14 of Set 9 | san quintin
# Processing Record 15 of Set 9 | samarai
# Processing Record 16 of Set 9 | araouane
# Processing Record 17 of Set 9 | hadejia
# Processing Record 18 of Set 9 | babu
# Processing Record 19 of Set 9 | tura
# Processing Record 20 of Set 9 | bismarck
# Processing Record 21 of Set 9 | pitimbu
# Processing Record 22 of Set 9 | katobu
# Processing Record 23 of Set 9 | thio
# Processing Record 24 of Set 9 | kloulklubed
# Processing Record 25 of Set 9 | plaster rock
# Processing Record 26 of Set 9 | vung tau
# Processing Record 27 of Set 9 | sobolevo
# Processing Record 28 of Set 9 | westport
# Processing Record 29 of Set 9 | narsaq
# Processing Record 30 of Set 9 | vidim
# Processing Record 31 of Set 9 | colonia
# Processing Record 32 of Set 9 | sinnamary
# Processing Record 33 of Set 9 | laslea
# Processing Record 34 of Set 9 | turochak
# Processing Record 35 of Set 9 | goderich
# Processing Record 36 of Set 9 | beringovskiy
# Processing Record 37 of Set 9 | fort nelson
# Processing Record 38 of Set 9 | komsomolskiy
# Processing Record 39 of Set 9 | bailleul
# Processing Record 40 of Set 9 | bridlington
# Processing Record 41 of Set 9 | college
# Processing Record 42 of Set 9 | nishihara
# Processing Record 43 of Set 9 | khormuj
# City not found. Skipping...
# Processing Record 44 of Set 9 | kulu
# Processing Record 45 of Set 9 | ihosy
# Processing Record 46 of Set 9 | guerrero negro
# Processing Record 47 of Set 9 | alihe
# Processing Record 48 of Set 9 | hornepayne
# Processing Record 49 of Set 9 | concordia
# Processing Record 50 of Set 9 | mayya
# Processing Record 1 of Set 10 | mizusawa
# Processing Record 2 of Set 10 | pavino
# Processing Record 3 of Set 10 | basco
# Processing Record 4 of Set 10 | kanadey
# Processing Record 5 of Set 10 | dhidhdhoo
# Processing Record 6 of Set 10 | chapais
# Processing Record 7 of Set 10 | amahai
# Processing Record 8 of Set 10 | loandjili
# Processing Record 9 of Set 10 | soe
# Processing Record 10 of Set 10 | charlottetown
# Processing Record 11 of Set 10 | gisborne
# Processing Record 12 of Set 10 | port hedland
# Processing Record 13 of Set 10 | bayeux
# Processing Record 14 of Set 10 | thinadhoo
# Processing Record 15 of Set 10 | berlevag
# Processing Record 16 of Set 10 | waipawa
# Processing Record 17 of Set 10 | mombetsu
# Processing Record 18 of Set 10 | havoysund
# Processing Record 19 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 20 of Set 10 | paamiut
# Processing Record 21 of Set 10 | praya
# Processing Record 22 of Set 10 | bandarbeyla
# Processing Record 23 of Set 10 | takhtamygda
# Processing Record 24 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 25 of Set 10 | paracuru
# Processing Record 26 of Set 10 | bantry
# Processing Record 27 of Set 10 | esmeraldas
# Processing Record 28 of Set 10 | praia
# Processing Record 29 of Set 10 | sydney
# Processing Record 30 of Set 10 | vyazemskiy
# Processing Record 31 of Set 10 | eyl
# Processing Record 32 of Set 10 | soavinandriana
# Processing Record 33 of Set 10 | paka
# Processing Record 34 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 35 of Set 10 | vanimo
# Processing Record 36 of Set 10 | chimbote
# Processing Record 37 of Set 10 | cooma
# Processing Record 38 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 10 | vila velha
# Processing Record 40 of Set 10 | belomorsk
# Processing Record 41 of Set 10 | usvyaty
# Processing Record 42 of Set 10 | palmer
# Processing Record 43 of Set 10 | tuy hoa
# Processing Record 44 of Set 10 | chokurdakh
# Processing Record 45 of Set 10 | shache
# Processing Record 46 of Set 10 | carballo
# Processing Record 47 of Set 10 | kutum
# Processing Record 48 of Set 10 | baunatal
# Processing Record 49 of Set 10 | kyaukse
# Processing Record 50 of Set 10 | northam
# Processing Record 1 of Set 11 | ossora
# Processing Record 2 of Set 11 | katangli
# Processing Record 3 of Set 11 | la asuncion
# Processing Record 4 of Set 11 | richards bay
# Processing Record 5 of Set 11 | mananara
# Processing Record 6 of Set 11 | wlodawa
# Processing Record 7 of Set 11 | cam ranh
# Processing Record 8 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 9 of Set 11 | yumen
# Processing Record 10 of Set 11 | litayen
# City not found. Skipping...
# Processing Record 11 of Set 11 | lichinga
# Processing Record 12 of Set 11 | bonnyville
# Processing Record 13 of Set 11 | tarakan
# Processing Record 14 of Set 11 | antigonish
# Processing Record 15 of Set 11 | kahului
# Processing Record 16 of Set 11 | dharchula
# Processing Record 17 of Set 11 | republic
# Processing Record 18 of Set 11 | dickson
# Processing Record 19 of Set 11 | glasgow
# Processing Record 20 of Set 11 | bastrop
# Processing Record 21 of Set 11 | toora-khem
# Processing Record 22 of Set 11 | botwood
# Processing Record 23 of Set 11 | cockburn town
# Processing Record 24 of Set 11 | lingyuan
# Processing Record 25 of Set 11 | muisne
# Processing Record 26 of Set 11 | novyy rogachik
# Processing Record 27 of Set 11 | victoria
# Processing Record 28 of Set 11 | khovu-aksy
# Processing Record 29 of Set 11 | saint-joseph
# Processing Record 30 of Set 11 | haapiti
# Processing Record 31 of Set 11 | sistranda
# Processing Record 32 of Set 11 | el vigia
# Processing Record 33 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 34 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 35 of Set 11 | homer
# Processing Record 36 of Set 11 | coihaique
# Processing Record 37 of Set 11 | ugoofaaru
# Processing Record 38 of Set 11 | itoman
# Processing Record 39 of Set 11 | fort saint james
# Processing Record 40 of Set 11 | yagodnoye
# Processing Record 41 of Set 11 | tutoia
# Processing Record 42 of Set 11 | umarizal
# Processing Record 43 of Set 11 | singkawang
# Processing Record 44 of Set 11 | naze
# Processing Record 45 of Set 11 | teknaf
# Processing Record 46 of Set 11 | novorudnyy
# Processing Record 47 of Set 11 | gagra
# Processing Record 48 of Set 11 | sibolga
# Processing Record 49 of Set 11 | udimskiy
# Processing Record 50 of Set 11 | chiredzi
# Processing Record 1 of Set 12 | ambilobe
# Processing Record 2 of Set 12 | gamboma
# Processing Record 3 of Set 12 | nipawin
# Processing Record 4 of Set 12 | ponnani
# Processing Record 5 of Set 12 | hovd
# Processing Record 6 of Set 12 | bayanday
# Processing Record 7 of Set 12 | ust-tarka
# Processing Record 8 of Set 12 | batagay-alyta
# Processing Record 9 of Set 12 | bac lieu
# Processing Record 10 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 11 of Set 12 | conceicao do araguaia
# Processing Record 12 of Set 12 | necochea
# Processing Record 13 of Set 12 | grants
# Processing Record 14 of Set 12 | nanortalik
# Processing Record 15 of Set 12 | marawi
# Processing Record 16 of Set 12 | martapura
# Processing Record 17 of Set 12 | auki
# Processing Record 18 of Set 12 | tiznit
# Processing Record 19 of Set 12 | nioro
# Processing Record 20 of Set 12 | tocopilla
# Processing Record 21 of Set 12 | togur
# Processing Record 22 of Set 12 | chakwal
# Processing Record 23 of Set 12 | praia da vitoria
# Processing Record 24 of Set 12 | leningradskiy
# Processing Record 25 of Set 12 | hastings
# Processing Record 26 of Set 12 | kracheh
# City not found. Skipping...
# Processing Record 27 of Set 12 | kathmandu
# Processing Record 28 of Set 12 | pimentel
# Processing Record 29 of Set 12 | cortez
# Processing Record 30 of Set 12 | ormara
# Processing Record 31 of Set 12 | urengoy
# Processing Record 32 of Set 12 | north bend
# Processing Record 33 of Set 12 | axim
# Processing Record 34 of Set 12 | puerto varas
# Processing Record 35 of Set 12 | gigmoto
# Processing Record 36 of Set 12 | sol-iletsk
# Processing Record 37 of Set 12 | cabedelo
# Processing Record 38 of Set 12 | carutapera
# Processing Record 39 of Set 12 | alexandria
# Processing Record 40 of Set 12 | benguela
# Processing Record 41 of Set 12 | oussouye
# Processing Record 42 of Set 12 | moree
# Processing Record 43 of Set 12 | qaqortoq
# Processing Record 44 of Set 12 | chuguyevka
# Processing Record 45 of Set 12 | avera
# Processing Record 46 of Set 12 | vila do maio
# Processing Record 47 of Set 12 | sovetskiy
# Processing Record 48 of Set 12 | oxapampa
# Processing Record 49 of Set 12 | solnechnyy
# Processing Record 50 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 13 | oxford
# Processing Record 2 of Set 13 | alindao
# Processing Record 3 of Set 13 | sidney
# Processing Record 4 of Set 13 | dujuma
# City not found. Skipping...
# Processing Record 5 of Set 13 | spassk-dalniy
# Processing Record 6 of Set 13 | constitucion
# Processing Record 7 of Set 13 | eenhana
# Processing Record 8 of Set 13 | sept-iles
# Processing Record 9 of Set 13 | kudahuvadhoo
# Processing Record 10 of Set 13 | kasongo-lunda
# Processing Record 11 of Set 13 | arinos
# Processing Record 12 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 13 | kaura namoda
# Processing Record 14 of Set 13 | maple creek
# Processing Record 15 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 16 of Set 13 | bull savanna
# Processing Record 17 of Set 13 | bahia blanca
# Processing Record 18 of Set 13 | bozeman
# Processing Record 19 of Set 13 | danli
# Processing Record 20 of Set 13 | abu zabad
# Processing Record 21 of Set 13 | hit
# Processing Record 22 of Set 13 | raha
# Processing Record 23 of Set 13 | katha
# City not found. Skipping...
# Processing Record 24 of Set 13 | antalaha
# Processing Record 25 of Set 13 | plettenberg bay
# Processing Record 26 of Set 13 | mabaruma
# Processing Record 27 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 28 of Set 13 | ulaangom
# Processing Record 29 of Set 13 | iquique
# Processing Record 30 of Set 13 | gweru
# Processing Record 31 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 32 of Set 13 | mountain home
# Processing Record 33 of Set 13 | shingu
# Processing Record 34 of Set 13 | fortuna
# Processing Record 35 of Set 13 | red deer
# Processing Record 36 of Set 13 | margate
# Processing Record 37 of Set 13 | svetlogorsk
# Processing Record 38 of Set 13 | kirakira
# Processing Record 39 of Set 13 | porterville
# Processing Record 40 of Set 13 | charyshskoye
# Processing Record 41 of Set 13 | ferkessedougou
# Processing Record 42 of Set 13 | karasuk
# Processing Record 43 of Set 13 | barkhan
# Processing Record 44 of Set 13 | clarence town
# Processing Record 45 of Set 13 | acarau
# Processing Record 46 of Set 13 | ambon
# Processing Record 47 of Set 13 | talaya
# Processing Record 48 of Set 13 | kifri
# Processing Record 49 of Set 13 | evensk
# Processing Record 50 of Set 13 | eureka
# Processing Record 1 of Set 14 | asfi
# Processing Record 2 of Set 14 | barcelona
# Processing Record 3 of Set 14 | tahe
# Processing Record 4 of Set 14 | imbituba
# Processing Record 5 of Set 14 | dilijan
# Processing Record 6 of Set 14 | jiuquan
# Processing Record 7 of Set 14 | lata
# Processing Record 8 of Set 14 | makinsk
# Processing Record 9 of Set 14 | plavinas
# Processing Record 10 of Set 14 | sioux lookout
# Processing Record 11 of Set 14 | agadez
# Processing Record 12 of Set 14 | batticaloa
# Processing Record 13 of Set 14 | upington
# Processing Record 14 of Set 14 | nanga eboko
# Processing Record 15 of Set 14 | schweinfurt
# Processing Record 16 of Set 14 | leshukonskoye
# Processing Record 17 of Set 14 | saint-pierre
# Processing Record 18 of Set 14 | chanthaburi
# Processing Record 19 of Set 14 | lorengau
# Processing Record 20 of Set 14 | shahabad
# Processing Record 21 of Set 14 | magistralnyy
# Processing Record 22 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 23 of Set 14 | bandar-e lengeh
# Processing Record 24 of Set 14 | bar bigha
# Processing Record 25 of Set 14 | vestmannaeyjar
# Processing Record 26 of Set 14 | cukai
# Processing Record 27 of Set 14 | charters towers
# Processing Record 28 of Set 14 | tevaitoa
# Processing Record 29 of Set 14 | nizhniy odes
# Processing Record 30 of Set 14 | galbshtadt
# Processing Record 31 of Set 14 | moron
# Processing Record 32 of Set 14 | santa fe
# Processing Record 33 of Set 14 | tessalit
# Processing Record 34 of Set 14 | fairbanks
# Processing Record 35 of Set 14 | leh
# Processing Record 36 of Set 14 | san juan
# Processing Record 37 of Set 14 | zhaoyang
# Processing Record 38 of Set 14 | salta
# Processing Record 39 of Set 14 | olafsvik
# Processing Record 40 of Set 14 | olinda
# Processing Record 41 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 42 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 43 of Set 14 | djambala
# Processing Record 44 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 45 of Set 14 | olga
# Processing Record 46 of Set 14 | rawson
# Processing Record 47 of Set 14 | tagusao
# Processing Record 48 of Set 14 | marzuq
# Processing Record 49 of Set 14 | monrovia
# Processing Record 50 of Set 14 | ushtobe
# Processing Record 1 of Set 15 | viedma
# Processing Record 2 of Set 15 | kongsberg
# Processing Record 3 of Set 15 | sechura
# Processing Record 4 of Set 15 | nadym
# Processing Record 5 of Set 15 | bentiu
# Processing Record 6 of Set 15 | pathein
# Processing Record 7 of Set 15 | okato
# Processing Record 8 of Set 15 | oblivskaya
# Processing Record 9 of Set 15 | povorino
# Processing Record 10 of Set 15 | teya
# Processing Record 11 of Set 15 | denpasar
# Processing Record 12 of Set 15 | zhigansk
# Processing Record 13 of Set 15 | redmond
# Processing Record 14 of Set 15 | fort-shevchenko
# Processing Record 15 of Set 15 | athabasca
# Processing Record 16 of Set 15 | osakarovka
# Processing Record 17 of Set 15 | chitungwiza
# Processing Record 18 of Set 15 | gardabani
# Processing Record 19 of Set 15 | honiara
# Processing Record 20 of Set 15 | mandera
# Processing Record 21 of Set 15 | bridgetown
# Processing Record 22 of Set 15 | quatre cocos
# Processing Record 23 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 24 of Set 15 | ulundurpettai
# City not found. Skipping...
# Processing Record 25 of Set 15 | diamantino
# Processing Record 26 of Set 15 | wana
# Processing Record 27 of Set 15 | sebeta
# Processing Record 28 of Set 15 | mocuba
# Processing Record 29 of Set 15 | muyezerskiy
# Processing Record 30 of Set 15 | fontem
# Processing Record 31 of Set 15 | copiapo
# Processing Record 32 of Set 15 | sirohi
# Processing Record 33 of Set 15 | belogorsk
# Processing Record 34 of Set 15 | kalabo
# Processing Record 35 of Set 15 | sinegorye
# Processing Record 36 of Set 15 | forbes
# Processing Record 37 of Set 15 | nelson bay
# Processing Record 38 of Set 15 | alvdal
# Processing Record 39 of Set 15 | mandalgovi
# Processing Record 40 of Set 15 | port augusta
# Processing Record 41 of Set 15 | dekoa
# City not found. Skipping...
# Processing Record 42 of Set 15 | cap malheureux
# Processing Record 43 of Set 15 | la macarena
# Processing Record 44 of Set 15 | henties bay
# Processing Record 45 of Set 15 | kerteh
# City not found. Skipping...
# Processing Record 46 of Set 15 | ignalina
# Processing Record 47 of Set 15 | huarmey
# Processing Record 48 of Set 15 | saint-francois
# Processing Record 49 of Set 15 | mount isa
# Processing Record 50 of Set 15 | ochakiv
# Processing Record 1 of Set 16 | coruripe
# Processing Record 2 of Set 16 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 16 | touros
# Processing Record 4 of Set 16 | cocal
# Processing Record 5 of Set 16 | sabha
# Processing Record 6 of Set 16 | iralaya
# Processing Record 7 of Set 16 | liverpool
# Processing Record 8 of Set 16 | mago
# Processing Record 9 of Set 16 | hirado
# Processing Record 10 of Set 16 | dovolnoye
# Processing Record 11 of Set 16 | mahibadhoo
# Processing Record 12 of Set 16 | harnosand
# Processing Record 13 of Set 16 | meghri
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 699

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Barrow      US  71.2906 -156.7887    -27.38        68          40
# 1        Busselton      AU -33.6500  115.3333     66.09        52           0
# 2         Cidreira      BR -30.1811  -50.2056     72.81        96         100
# 3         Orotukan      RU  62.2667  151.7000    -28.23       100          86
# 4         Damietta      EG  31.4165   31.8133     55.29        75          54
# 5           Hobart      AU -42.8794  147.3294     59.25        86          75
# 6  Bambous Virieux      MU -20.3428   57.7575     79.21        94          75
# 7           Dingle      PH  10.9995  122.6711     73.44        92         100
# 8      Pietersburg      ZA -23.9045   29.4688     54.00        85          29
# 9     Punta Arenas      CL -53.1500  -70.9167     55.51        50           0
#
#    Wind Speed Current Description
# 0        8.05                haze
# 1        4.16           clear sky
# 2        4.00     overcast clouds
# 3        3.60     overcast clouds
# 4       17.07       broken clouds
# 5        6.91       broken clouds
# 6       16.11       moderate rain
# 7       10.18     overcast clouds
# 8       10.54    scattered clouds
# 9        8.05           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
